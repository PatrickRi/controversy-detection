# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import os
import seaborn as sns

# %%
df = pd.read_csv('keyword_used_count_small.csv', names=['keyword', 'cnt'], sep=';')
df['cnt'] = pd.to_numeric(df['cnt'])

# %%
g1 = sns.barplot(x="keyword", y="cnt", data=df)
g1.set(xticklabels=[])
plt.show()

# %%
df.describe()

# %%
pd.to_numeric(df['cnt'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas\_libs\lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "cnt"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-0a245f435b50> in <module>
# ----> 1 pd.to_numeric(df['cnt'])
#       2
#       3
#
# c:\users\patrick\appdata\local\programs\python\python37\lib\site-packages\pandas\core\tools\numeric.py in to_numeric(arg, errors, downcast)
#     133             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     134             values = lib.maybe_convert_numeric(values, set(),
# --> 135                                                coerce_numeric=coerce_numeric)
#     136
#     137     except Exception:
#
# ...

# %%
df = pd.read_csv('Keywords_MeanPostings_filteredgreater4.csv', names=['keyword', 'avg', 'cnt'], sep=';')
df['cnt'] = pd.to_numeric(df['cnt'])
df['avg'] = pd.to_numeric(df['avg'])
df.describe()
# Out:
#                 avg           cnt
# count  39447.000000  39447.000000
# mean     117.198925     42.561462
# std      124.859511    412.952641
# min        1.000000      5.000000
# 25%       41.000000      6.000000
# 50%       83.000000     10.000000
# 75%      148.000000     21.000000
# max     2769.000000  53144.000000

# %%
df['asdf'] = df.index.values
df = df.sort_values(by=['avg'])
g1 = sns.distplot(df["avg"])
#g1.set(xticklabels=[])
#g1.set_xscale('log')
plt.show()

# %%
sns.distplot(df["avg"], kde=False)

# %%
g = sns.jointplot("avg", "cnt", data=df, height=10, ratio=3,
                  marginal_kws=dict(bins=50))
g.ax_joint.set_xscale('log')
g.ax_joint.set_yscale('log')
