# %%
import pandas as pd
import os
import numpy as np
import networkx as nx
import igraph as ig
import glob
from measures.BCC import BCC
from measures.CC import ClusteringCoefficient
from measures.EC import EmbeddingControversy
from measures.GMCK import BoundaryConnectivity
from measures.MBLB import MBLB
from measures.modularity import Modularity
from measures.PI import PolarizationIndex
from measures.RWC import RWC
from polarization_analysis.utils import postings_df_to_graph, partition, normalize
from measures.utils import get_config, get_logger, get_partitions, normalize_graph, get_node_percentage
from measures.utils import __read_partition_file
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

# %%
txtfile = open("results_postings_min_2_weight.txt")
lines = txtfile.readlines()
data = []
for line in lines:
    line = line.strip()
    elements = line.split("  ")
    if len(elements) > 3:
        data.append(elements)

df = pd.DataFrame(data=data, columns=['docid', 'mean', 'measure', 'result'])
df["result"] = pd.to_numeric(df["result"])
def filtermeasure(text):
  if text in ['EmbeddingControversy', 'CORR30', 'BC', 'BoundaryConnectivity', 'MBLB', 'Modularity', 'PolarizationIndex', 'RWC', 'UMAP30']:
    return 1
  else:
    return 0

df = df[df['measure'].apply(filtermeasure) != 0]

# %%
df.head(10)
# Out:
#             docid  mean               measure    result
# 1   2000067189399  mean  BoundaryConnectivity  0.172323
# 2   2000067189399  mean  EmbeddingControversy  0.000039
# 3   2000067189399  mean  MBLB                  0.612621
# 4   2000067189399  mean  Modularity            0.439481
# 5   2000067189399  mean  PolarizationIndex     0.721775
# 6   2000067189399  mean  RWC                   0.255764
# 8   2000103364196  mean  BoundaryConnectivity  0.226936
# 9   2000103364196  mean  MBLB                  0.762456
# 10  2000103364196  mean  Modularity            0.472476
# 11  2000103364196  mean  PolarizationIndex     0.861755

# %%
df.describe()
# Out:
#            result
# count  674.000000
# mean   0.410481
# std    0.257516
# min    0.000039
# 25%    0.195652
# 50%    0.433732
# 75%    0.617704
# max    0.951047

# %%
df[['measure', 'result']].groupby(['measure']).describe()
# Out:
#                      result                                                    \
#                       count      mean       std       min       25%       50%
# measure
# BoundaryConnectivity  124.0  0.195396  0.043365  0.021429  0.174358  0.195085
# EmbeddingControversy  64.0   0.017723  0.017069  0.000039  0.004853  0.012077
# MBLB                  124.0  0.574411  0.155332  0.124384  0.463406  0.590526
# Modularity            124.0  0.445400  0.038828  0.112883  0.435136  0.451123
# PolarizationIndex     124.0  0.762790  0.109862  0.188966  0.698379  0.780088
# RWC                   114.0  0.265426  0.159091  0.010126  0.138462  0.247373
#
#
#                            75%       max
# measure
# BoundaryConnectivity  0.225221  0.307198
# EmbeddingControversy  0.026445  0.074457
# MBLB                  0.675513  0.881308
# Modularity            0.465223  0.488824
# PolarizationIndex     0.843317  0.951047
# RWC                   0.346088  0.719943

# %%
posting_dirs = glob.glob('./cache/postings*')
for posting_dir in posting_dirs:
    articles = glob.glob(os.path.join('.', posting_dir, '*'))
    for article in articles:
        gml_path = glob.glob(os.path.join('.', article, '*.gml'))
        graph = nx.read_gml(gml_path[0], label='id')
        iggraph: ig.Graph = ig.read(gml_path)
        g, node_mapping = normalize(graph)
        left_path = glob.glob(os.path.join('.', article, 'left', '*.txt'))
        right_path = glob.glob(os.path.join('.', article, 'right', '*.txt'))
        left_part = __read_partition_file(left_path)
        right_part = __read_partition_file(right_path)
        doc_id = article
        measures_dict = {
            "BCC": BCC(g, iggraph, node_mapping, left_part, right_part, doc_id, cache=False),
            "BC": BoundaryConnectivity(g, iggraph, node_mapping, left_part, right_part, doc_id),
            # ClusteringCoefficient(g, iggraph, node_mapping, left_part, right_part, doc_id),
            "EC": EmbeddingControversy(g, iggraph, node_mapping, left_part, right_part, doc_id),
            "ECU(corr)": EmbeddingControversy(g, iggraph, node_mapping, left_part, right_part, doc_id, 'umap', 15, 'correlation'),
            "ECU(n30)": EmbeddingControversy(g, iggraph, node_mapping, left_part, right_part, doc_id, 'umap', 30),
            "MBLB": MBLB(g, iggraph, node_mapping, left_part, right_part, doc_id, percent=percent),
            "Modularity": Modularity(g, iggraph, node_mapping, left_part, right_part, doc_id),
            "PolarizationIndex": PolarizationIndex(g, iggraph, node_mapping, left_part, right_part, doc_id, cache=False),
            "RWC": RWC(g, iggraph, node_mapping, left_part, right_part, doc_id, percent=percent)
        }
        percent = get_node_percentage(g.number_of_nodes())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-f2a4140fde36> in <module>
#       5         gml_path = glob.glob(os.path.join('.', article, '*.gml'))
#       6         graph = nx.read_gml(gml_path[0], label='id')
# ----> 7         iggraph: ig.Graph = ig.read(gml_path)
#       8         g, node_mapping = normalize(graph)
#       9         left_path = glob.glob(os.path.join('.', article, 'left', '*.txt'))
#
# c:\users\patrick\appdata\local\programs\python\python37\lib\site-packages\igraph\__init__.py in read(filename, *args, **kwds)
#    4061     @param filename: the name of the file to be loaded
#    4062     """
# -> 4063     return Graph.Read(filename, *args, **kwds)
#    4064 load=read
#    4065
#
# c:\users\patrick\appdata\local\programs\python\python37\lib\site-packages\igraph\__init__.py in Read(klass, f, format, *args, **kwds)
#    2213         """
#    2214         if format is None:
# -> 2215             format = klass._identify_format(f)
#    2216         try:
#    2217             reader = klass._format_mapping[format][0]
#
# c:\users\patrick\appdata\local\programs\python\python37\lib\site-packages\igraph\__init__.py in _identify_format(klass, filename)
#    2143                 return None
#    2144
# -> 2145         root, ext = os.path.splitext(filename)
#    2146         ext = ext.lower()
#    2147
#
# c:\users\patrick\appdata\local\programs\python\python37\lib\ntpath.py in splitext(p)
#     200
#     201 def splitext(p):
# --> 202     p = os.fspath(p)
#     203     if isinstance(p, bytes):
#     204         return genericpath._splitext(p, b'\\', b'/', b'.')
#
# TypeError: expected str, bytes or os.PathLike object, not list

# %%
import glob
import os

import pandas as pd

from measures.utils import get_logger

pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', None)

logger = get_logger('main')
posting_dirs = glob.glob('./cache/postings*')
df_all = pd.DataFrame(
    columns=['measure', 'result', 'title', 'removed_edges', 'ratio_edges_removed', 'largest_cc', 'ratio_largest_cc',
             'experiment', 'doc_id'])
for posting_dir in posting_dirs:
    articles = glob.glob(os.path.join('.', posting_dir, '*'))
    experiment = posting_dir.split(os.sep)[-1]
    if experiment == 'postings_weight2':
        break
    for article in articles:
        doc_id = article.split(os.sep)[-1]
        # gml_path = glob.glob(os.path.join('.', article, '*.gml'))[0]
        # graph = nx.read_gml(gml_path, label='id')
        statistics_path = glob.glob(os.path.join('.', article, '*statistics.csv'))[0]
        df_statistics = pd.read_csv(statistics_path,
                                    names=['removed_edges', 'ratio_edges_removed', 'largest_cc', 'ratio_largest_cc'],
                                    header=0)
        scores_path = glob.glob(os.path.join('.', article, 'scores_*.csv'))[0]
        df_scores = pd.read_csv(scores_path,
                                names=['idx', 'measure', 'result'], header=0)
        df_scores = df_scores.drop(columns=['idx'])

        doc_title = glob.glob(os.path.join('.', article, '*.txt'))[0].split(os.sep)[-1].split('.txt')[0]
        df_scores['title'] = doc_title
        df_scores['removed_edges'] = df_statistics.iloc[0]['removed_edges']
        df_scores['ratio_edges_removed'] = df_statistics.iloc[0]['ratio_edges_removed']
        df_scores['largest_cc'] = df_statistics.iloc[0]['largest_cc']
        df_scores['ratio_largest_cc'] = df_statistics.iloc[0]['ratio_largest_cc']
        df_scores['experiment'] = experiment
        df_scores['doc_id'] = doc_id
        df_all = pd.concat([df_all, df_scores])

# %%
df_all.describe()
# Out:
#              result  removed_edges  ratio_edges_removed    largest_cc  \
# count  44881.000000  44881.000000   44881.000000         44881.000000
# mean   0.295765      81.767563      1.758221             286.753080
# std    0.251519      102.216277     2.491356             414.718784
# min   -1.094336      0.000000       0.000000             3.000000
# 25%    0.121976      0.000000       0.000000             32.000000
# 50%    0.288625      0.000000       0.000000             146.000000
# 75%    0.448897      198.000000     3.444444             189.000000
# max    0.985714      288.000000     11.545455            2495.000000
#
#        ratio_largest_cc
# count  44881.000000
# mean   0.617001
# std    0.382218
# min    0.015152
# 25%    0.176136
# 50%    0.865385
# 75%    0.955947
# max    1.000000

# %%
df_all.head(5)
# Out:
#      measure    result                                 title  removed_edges  \
# 0  BCC        0.481717  Das_Comeback_der_Theologie_im_Westen  0.0
# 1  BC         0.173902  Das_Comeback_der_Theologie_im_Westen  0.0
# 2  EC         0.337850  Das_Comeback_der_Theologie_im_Westen  0.0
# 3  ECU(corr)  0.073312  Das_Comeback_der_Theologie_im_Westen  0.0
# 4  ECU(n30)   0.041831  Das_Comeback_der_Theologie_im_Westen  0.0
#
#    ratio_edges_removed  largest_cc  ratio_largest_cc    experiment  \
# 0  0.0                  122.0       0.953125          postings_500
# 1  0.0                  122.0       0.953125          postings_500
# 2  0.0                  122.0       0.953125          postings_500
# 3  0.0                  122.0       0.953125          postings_500
# 4  0.0                  122.0       0.953125          postings_500
#
#           doc_id
# 0  2000009955231
# 1  2000009955231
# 2  2000009955231
# 3  2000009955231
# 4  2000009955231

# %%
df = df_all.copy()
df = df[df["measure"] == 'BC']
df.describe()
# Out:
#             result  removed_edges  ratio_edges_removed   largest_cc  \
# count  4659.000000  4659.000000    4659.000000          4659.000000
# mean   0.147698     87.615368      1.889238             226.270659
# std    0.070325     103.333414     2.541508             350.943246
# min   -0.070988     0.000000       0.000000             3.000000
# 25%    0.108161     0.000000       0.000000             29.000000
# 50%    0.155085     0.000000       0.000000             134.000000
# 75%    0.197009     200.000000     3.616667             179.000000
# max    0.375000     288.000000     11.545455            2495.000000
#
#        ratio_largest_cc
# count  4659.000000
# mean   0.591711
# std    0.383770
# min    0.015152
# 25%    0.158470
# 50%    0.821596
# 75%    0.945055
# max    1.000000

# %%
df.sort_values(axis=0, by=('result'), ascending=False).drop_duplicates(subset=['title'])
# Out:
#    measure    result  \
# 1   BC      0.375000
# 28  BC      0.330272
# 55  BC      0.328571
# 55  BC      0.325000
# 37  BC      0.303571
# 73  BC      0.303571
# 82  BC      0.300000
# 82  BC      0.299812
# 82  BC      0.280952
# 1   BC      0.275000
# 73  BC      0.275000
# 28  BC      0.271111
# 64  BC      0.266667
# 37  BC      0.261905
# 37  BC      0.260315
# 37  BC      0.255717
# 19  BC      0.255339
# 73  BC      0.254762
# 73  BC      0.250467
# 73  BC      0.250000
# 37  BC      0.250000
# 28  BC      0.250000
# 64  BC      0.250000
# 82  BC      0.250000
# 82  BC      0.250000
# 19  BC      0.250000
# 82  BC      0.250000
# 82  BC      0.248106
# 82  BC      0.246062
# 73  BC      0.244678
# ..  ..           ...
# 1   BC      0.069145
# 1   BC      0.066227
# 1   BC      0.065839
# 1   BC      0.065479
# 1   BC      0.061515
# 1   BC      0.061430
# 1   BC      0.059088
# 37  BC      0.058074
# 19  BC      0.057599
# 1   BC      0.055240
# 1   BC      0.051610
# 10  BC      0.051024
# 82  BC      0.049945
# 1   BC      0.048626
# 10  BC      0.046351
# 1   BC      0.044419
# 1   BC      0.043070
# 1   BC      0.041116
# 82  BC      0.040424
# 1   BC      0.039629
# 73  BC      0.035705
# 82  BC      0.030654
# 1   BC      0.027386
# 1   BC      0.025482
# 82  BC      0.017340
# 1   BC      0.002251
# 46  BC     -0.002969
# 1   BC     -0.004103
# 55  BC     -0.012821
# 1   BC     -0.018876
#
#                                                                                                   title  \
# 1   Rotes_Kreuz_bangt_um_Jobs_für_Sanitäter
# 28  Ich_bin_ein_Hofer-Anhänger_Diskonter-Lkws_irritieren_Kunden
# 55  Eine_14-jährige_Youtuberin_ist_der_neue_Kinderstar_der_Rechtsextremen
# 55  Druck_auf_Frankreichs_Behörden_wächst
# 37  Grüne_wollen_Hofburg_trumpsicher_machen
# 73  Evakuierung_Ost-Aleppos_soll_fortgesetzt_werden
# 82  Wenn_Essen_und_Trinken_krankmacht
# 82  Anschlagspläne_vereitelt_Antiterroreinsatz_in_der_Nähe_von_Paris
# 82  Nach_Anschlag_in_London_Polizei_verhaftet_18-Jährigen
# 1   Immer_mehr_Volksschüler_verbreiten_Sexvideos_und_Nacktbilder
# 73  Nach_Ende_für_Gratis-Upgrade_Windows_10_geht_die_Luft_aus
# 28  Google_Unachtsame_Autofahrer_Schuld_an_Unfällen_mit_selbstfahrenden_Autos
# 64  Kopftuchverbot_an_Schulen_Umsetzung_ohne_Opposition_möglich
# 37  Moser_Sicherungshaft_kann_bis_zu_18_Monate_dauern
# 37  Häupl_stellt_SPÖ-Blockade_bei_Wiener_Wahlrecht_in_Aussicht
# 37  Whatsapp_ab_sofort_gratis__Netflix_sieht_Youtube_als_Konkurrenz
# 19  Ägypten_Aufregung_im_Netz_wegen_nacktem_Paar_auf_Cheopspyramide
# 73  Wieder_Streit_um_Hitlers_Geburtshaus
# 73  Hans_Niessl_Faymann_haben_ganz_andere_geschadet
# 73  Causa_Tempelberg_Hofer_reicht_Beschwerde_bei_Medienbehörde_ein
# 37  Kurz-Wahlplakat_Die_Fleißigen_und_die_Faulen
# 28  Boeing-Aktie_nach_Flugzeugabsturz_mit_größtem_Minus_seit_2001
# 64  Ex-Spiegel-Reporter_Claas_Relotius_Zu_gut_um_wahr_zu_sein
# 82  Kitzmüllers_neuer_Büroleiter_einst_für_Berufsschwuchtel_verurteilt
# 82  Microsoft_enthüllt_Surface_Pro_4_Surface_Book_und_Lumia-950-Smartphones
# 19  Sicherungshaft_würde_das_Rechtsgefüge_zerstören
# 82  Bilanz_nach_acht_Jahren_Obama_Hohe_Hoffnungen_wenig_Wandel
# 82  Rauchverbot_Ja_nein_weiß_nicht
# 82  Aufregung_um_Nazi-Lego_auf_Amazon
# 73  Wiens_Angst_um_den_Hundstrümmerl-Frieden
# ..                                       ...
# 1   Der_kleinlichste_Grund_aus_dem_Sie_Schluss_gemacht_haben
# 1   Nach_Festnahme_SPÖ_entlässt_Wahlkampfberater_Silberstein
# 1   Ansbach_Handyvideo_deutet_auf_islamistisches_Motiv_hin
# 1   Pamela_Rendi-Wagner_zu_Migration_Werde_nicht_die_Ängste_ausnützen
# 1   Strache_soll_Staatsaufträge_für_Wahlkampfspenden_in_Aussicht_gestellt_haben
# 1   Dirty_Campaigning_Laut_Silberstein_wusste_Kern_nichts_von_Facebook-Seiten
# 1   Vassilakou_zu_Asyl_Wien_springt_ein_wenn_Bund_Gelder_kürzt
# 37  Übergriffe_in_Köln_Vier_Verdächtige_ermittelt_über_100_Anzeigen_eingegangen
# 19  Anschlag_auf_Pariser_Satiremagazin_Charlie_Hebdo_Zwölf_Tote_und_zahlreiche_Verletzte
# 1   Van_der_Bellen_sorgt_mit_Statement_zu_Kopftuch_für_Aufregung
# 1   Islamstudie_unter_Manipulationsverdacht_Kritik_an_Kurz_Uni_prüft
# 10  Tränengas_gegen_Flüchtlinge_an_griechisch-mazedonischer_Grenze
# 82  Nach_Köln-Übergriffen_Polizeipräsident_wird_in_Ruhestand_versetzt
# 1   Identitären-Demo_in_Wien_Festnahmen_und_Verletzte
# 10  Türkei_schoss_russisches_Kampfflugzeug_an_syrischer_Grenze_ab__Ankara_beruft_Nato-Sondersitzung_ein
# 1   Silberstein-Mitarbeiter_Puller_Kurz-Sprecher_bot_100_000_Euro_für_Infos__ÖVP_dementiert
# 1   Geiselnahme_in_Kirche_in_Nordfrankreich_Ein_Attentäter_trug_Fußfessel
# 1   Kurz_will_als_Kanzler_Richtlinienkompetenz
# 82  Immer_mehr_Anzeigen_wegen_Übergriffen_in_Köln__Zahl_der_Täter_unbekannt
# 1   Messerattacken_in_Wien_67-Jähriger_nicht_mehr_in_Lebensgefahr
# 73  Entsetzen_nach_Übergriffen_auf_Frauen_Krisentreffen_in_Köln
# 82  Tausende_Flüchtlinge_in_Spielfeld_Lage_angespannt
# 1   Teenager-Mord_in_Wr__Neustadt_U-Haft_verhängt
# 1   Israel_setzt_Zusammenarbeit_mit_Unesco_aus
# 82  Mazedonien_beugt_sich_Hunderte_Flüchtlinge_überqueren_Grenze
# 1   Fußi_bot_Silberstein-Übersetzerin_Geld_für_Mails_SPÖ_distanziert_sich_von_Berater
# 46  NFL-Liveforum_2016_Playoffs_Diskutieren_Sie_über_American_Football
# 1   Knalleffekt_SP-Bundesgeschäftsführer_Niedermühlbichler_tritt_zurück
# 55  Erinnern_an_den_Kosovo-Krieg_durch_die_nationalistische_Brille
# 1   Volkspartei_greift_vor_Kern-Interview_ORF_an
#
#     removed_edges  ratio_edges_removed  largest_cc  ratio_largest_cc  \
# 1   219.0          4.055556             35.0        0.230263
# 28  0.0            0.000000             165.0       0.800971
# 55  233.0          5.547619             14.0        0.058824
# 55  245.0          4.900000             23.0        0.106481
# 37  211.0          4.057692             14.0        0.072539
# 73  217.0          4.018519             40.0        0.303030
# 82  222.0          3.313433             42.0        0.202899
# 82  204.0          3.044776             38.0        0.180952
# 82  200.0          2.941176             46.0        0.232323
# 1   248.0          5.904762             12.0        0.060606
# 73  215.0          3.307692             35.0        0.181347
# 28  233.0          3.328571             47.0        0.247368
# 64  208.0          3.301587             37.0        0.228395
# 37  202.0          4.122449             33.0        0.189655
# 37  0.0            0.000000             161.0       0.809045
# 37  0.0            0.000000             220.0       0.890688
# 19  0.0            0.000000             190.0       0.852018
# 73  213.0          4.176471             23.0        0.132948
# 73  0.0            0.000000             189.0       0.904306
# 73  184.0          4.279070             15.0        0.083799
# 37  186.0          3.875000             11.0        0.063218
# 28  246.0          4.241379             25.0        0.115741
# 64  220.0          4.680851             22.0        0.120219
# 82  183.0          5.228571             25.0        0.128205
# 82  244.0          5.083333             16.0        0.084211
# 19  205.0          3.306452             11.0        0.065089
# 82  210.0          5.000000             25.0        0.138889
# 82  200.0          2.777778             49.0        0.302469
# 82  0.0            0.000000             169.0       0.782407
# 73  0.0            0.000000             152.0       0.921212
# ..  ...                 ...               ...            ...
# 1   0.0            0.000000             998.0       0.977473
# 1   0.0            0.000000             881.0       0.966009
# 1   0.0            0.000000             1708.0      0.994179
# 1   0.0            0.000000             913.0       0.980666
# 1   0.0            0.000000             2414.0      0.970647
# 1   0.0            0.000000             870.0       0.981941
# 1   0.0            0.000000             780.0       0.989848
# 37  0.0            0.000000             849.0       0.991822
# 19  0.0            0.000000             1703.0      0.987246
# 1   0.0            0.000000             1402.0      0.980420
# 1   0.0            0.000000             1009.0      0.981518
# 10  0.0            0.000000             1173.0      0.991547
# 82  0.0            0.000000             780.0       0.976220
# 1   0.0            0.000000             1169.0      0.982353
# 10  0.0            0.000000             1011.0      0.962857
# 1   0.0            0.000000             1290.0      0.979499
# 1   0.0            0.000000             2033.0      0.992191
# 1   0.0            0.000000             942.0       0.982273
# 82  0.0            0.000000             1514.0      0.998681
# 1   0.0            0.000000             1942.0      0.990816
# 73  0.0            0.000000             830.0       0.994012
# 82  0.0            0.000000             1034.0      0.991371
# 1   0.0            0.000000             1263.0      0.996843
# 1   96.0           1.043478             43.0        0.651515
# 82  0.0            0.000000             767.0       0.990956
# 1   0.0            0.000000             1407.0      0.985985
# 46  0.0            0.000000             218.0       0.981982
# 1   0.0            0.000000             1569.0      0.985553
# 55  108.0          1.173913             36.0        0.590164
# 1   0.0            0.000000             1077.0      0.984461
#
#               experiment         doc_id
# 1   postings_500_weight2  2000011003206
# 28  postings_500          2000035860022
# 55  postings_500_weight2  2000103161690
# 55  postings_500_weight2  2000025854723
# 37  postings_500_weight2  2000053945808
# 73  postings_500_weight2  2000049468554
# 82  postings_500_weight2  2000077364979
# 82  postings_500_weight2  2000033617679
# 82  postings_500_weight2  2000064153100
# 1   postings_500_weight2  2000098052467
# 73  postings_500_weight2  2000045343832
# 28  postings_500_weight2  2000019349999
# 64  postings_500_weight2  2000077369804
# 37  postings_500_weight2  2000099557390
# 37  postings_500          2000011810211
# 37  postings_500          2000029270335
# 19  postings_500          2000093461126
# 73  postings_500_weight2  2000014469212
# 73  postings_500          2000094865123
# 73  postings_500_weight2  2000038017646
# 37  postings_500_weight2  2000064756195
# 28  postings_500_weight2  2000099313332
# 64  postings_500_weight2  2000094426368
# 82  postings_500_weight2  2000100882124
# 82  postings_500_weight2  2000023300068
# 19  postings_500_weight2  2000101700146
# 82  postings_500_weight2  2000050717019
# 82  postings_500_weight2  2000073471091
# 82  postings_500          2000070014103
# 73  postings_500          2000082538148
# ..           ...                    ...
# 1   postings_top          2000097146278
# 1   postings_top          2000062638686
# 1   postings_top          2000041729911
# 1   postings_top          2000088333356
# 1   postings_top          2000103364196
# 1   postings_top          2000065228620
# 1   postings_top          2000053562077
# 37  postings_top          2000028563372
# 19  postings_top          2000010076421
# 1   postings_top          2000056579232
# 1   postings_top          2000060766463
# 10  postings_top          2000031961692
# 82  postings_top          2000028662791
# 1   postings_top          2000038643468
# 10  postings_top          2000026307773
# 1   postings_top          2000065417586
# 1   postings_top          2000041815368
# 1   postings_top          2000064636685
# 82  postings_top          2000028523248
# 1   postings_top          2000075673167
# 73  postings_top          2000028502118
# 82  postings_top          2000024247292
# 1   postings_top          2000096084363
# 1   postings_500_weight2  2000045888993
# 82  postings_top          2000021119514
# 1   postings_top          2000065531147
# 46  postings_top          2000021881754
# 1   postings_top          2000065079710
# 55  postings_500_weight2  2000100543676
# 1   postings_top          2000063511763
#
# [400 rows x 9 columns]

# %%
df = df_all.copy()
df = df[df["measure"] == 'BC']
df = df[df["experiment"] == 'postings_top']
df.sort_values(axis=0, by=('result'), ascending=False).drop_duplicates(subset=['title'])
# Out:
#    measure    result  \
# 1   BC      0.194809
# 1   BC      0.182986
# 46  BC      0.178722
# 1   BC      0.178073
# 1   BC      0.175625
# 1   BC      0.174583
# 1   BC      0.171820
# 1   BC      0.167422
# 1   BC      0.166611
# 1   BC      0.166144
# 73  BC      0.164012
# 1   BC      0.162569
# 1   BC      0.157402
# 1   BC      0.157355
# 1   BC      0.156262
# 1   BC      0.154346
# 1   BC      0.154193
# 1   BC      0.152896
# 1   BC      0.152396
# 1   BC      0.152211
# 82  BC      0.151466
# 1   BC      0.149819
# 1   BC      0.148955
# 1   BC      0.148772
# 1   BC      0.148623
# 1   BC      0.148526
# 1   BC      0.148434
# 1   BC      0.148144
# 1   BC      0.147915
# 10  BC      0.147706
# ..  ..           ...
# 1   BC      0.069388
# 10  BC      0.069198
# 1   BC      0.069145
# 1   BC      0.066227
# 1   BC      0.065839
# 1   BC      0.065479
# 1   BC      0.061515
# 1   BC      0.061430
# 1   BC      0.059088
# 1   BC      0.058074
# 82  BC      0.057599
# 1   BC      0.055240
# 1   BC      0.051610
# 64  BC      0.051024
# 10  BC      0.049945
# 1   BC      0.048626
# 82  BC      0.046351
# 1   BC      0.044419
# 1   BC      0.043070
# 1   BC      0.041116
# 82  BC      0.040424
# 1   BC      0.039629
# 37  BC      0.035705
# 64  BC      0.030654
# 1   BC      0.027386
# 10  BC      0.017340
# 1   BC      0.002251
# 55  BC     -0.002969
# 1   BC     -0.004103
# 1   BC     -0.018876
#
#                                                                                                   title  \
# 1   Dem_Expertenkabinett_des_Kanzlers_droht_ein_schnelles_Ende
# 1   Vassilakou_Die_Botschaft_der_Wähler_ist_angekommen
# 46  Red-Bull-Sender_Servus_TV_stellt_Betrieb_ein_geplanter_Betriebsrat_als_Mitgrund
# 1   Harald_Vilimsky_droht_Armin_Wolf_und_erntet_Kritik_von_Medienminister_Blümel
# 1   Welcher_Austausch_der_Bevölkerung_in_Österreich_tatsächlich_stattfindet
# 1   Richter_Bei_Kopftuchverbot_auch_kein_Kreuz_im_Gericht
# 1   Maurer_kündigt_Berufung_an_Notfalls_gehe_ich_bis_nach_Straßburg
# 1   Kurz_legt_Erdoğan-Anhängern_Verlassen_Österreichs_nahe
# 1   Vorläufiges_Endergebnis_Hofer_353_Van_der_Bellen_213
# 1   Wahlkarten_ausgezählt_Alexander_Van_der_Bellen_ist_Bundespräsident
# 73  Stenzel_kandidiert_auf_Liste_der_FPÖ
# 1   FPÖ-Gesundheitssprecherin_Anti-Raucher-Volksbegehren_unseriös
# 1   Für_Strache_hat_Udo_Landbauer_die_rote_Linie_noch_nicht_überschritten
# 1   Erfolglose_Jobvermittlung_Wenn_statt_dem_Franzi_der_Ali_kommt
# 1   Werbung_mit_kopftuchtragender_Frau_Rechter_Shitstorm_gegen_Bipa
# 1   Strache_und_Kurz_machen_jeweils_anderen_für_Raucherschlamassel_verantwortlich
# 1   IS-Kämpfer_will_heim_nach_Wien
# 1   Wiener_Lokal_verweigerte_FPÖ-Vizebürgermeister_Gudenus_die_Bedienung
# 1   ÖVP_bringt_SPÖ_in_Bredouille_Mit_Kern_sei_gar_nichts_möglich
# 1   Flüchtlingsthema_katapultiert_Strache_auf_Platz_eins
# 82  Diskussion_zur_Wien-Wahl_Politische_Zwerge_Integration_und_Öffis
# 1   Gutachten_für_Hofer_empfiehlt_Tempo_100
# 1   Innenministerium_beschränkt_Infos_für_kritische_Medien
# 1   Eskalation_zwischen_Türkei_und_den_Niederlanden
# 1   Causa_Pilz_Die_Zeit_der_alten_weißen_Männer_ist_vorbei
# 1   Fremdenpolizist_zerkratzte_Foto_auf_Visum_Deal_with_it
# 1   ÖVP_schließt_Dönmez_nach_sexistischem_Tweet_aus_Parlamentsklub_aus
# 1   In_der_SPÖ_rumort_es_nicht_nur_wegen_des_schlechten_Ergebnisses_bei_der_EU-Wahl
# 1   Regierung_will_Anonymität_im_Netz_abschaffen__mit_hohen_Strafen
# 10  Präsidentenwahl_Das_Endergebnis_im_Detail
# ..                                        ...
# 1   Zwölfstundentag_Neues_Arbeitszeitgesetz_beschlossen
# 10  Flüchtlinge_verlassen_Idomeni__Athen_Organisierte_Flugblattaktion
# 1   Der_kleinlichste_Grund_aus_dem_Sie_Schluss_gemacht_haben
# 1   Nach_Festnahme_SPÖ_entlässt_Wahlkampfberater_Silberstein
# 1   Ansbach_Handyvideo_deutet_auf_islamistisches_Motiv_hin
# 1   Pamela_Rendi-Wagner_zu_Migration_Werde_nicht_die_Ängste_ausnützen
# 1   Strache_soll_Staatsaufträge_für_Wahlkampfspenden_in_Aussicht_gestellt_haben
# 1   Dirty_Campaigning_Laut_Silberstein_wusste_Kern_nichts_von_Facebook-Seiten
# 1   Vassilakou_zu_Asyl_Wien_springt_ein_wenn_Bund_Gelder_kürzt
# 1   Übergriffe_in_Köln_Vier_Verdächtige_ermittelt_über_100_Anzeigen_eingegangen
# 82  Anschlag_auf_Pariser_Satiremagazin_Charlie_Hebdo_Zwölf_Tote_und_zahlreiche_Verletzte
# 1   Van_der_Bellen_sorgt_mit_Statement_zu_Kopftuch_für_Aufregung
# 1   Islamstudie_unter_Manipulationsverdacht_Kritik_an_Kurz_Uni_prüft
# 64  Tränengas_gegen_Flüchtlinge_an_griechisch-mazedonischer_Grenze
# 10  Nach_Köln-Übergriffen_Polizeipräsident_wird_in_Ruhestand_versetzt
# 1   Identitären-Demo_in_Wien_Festnahmen_und_Verletzte
# 82  Türkei_schoss_russisches_Kampfflugzeug_an_syrischer_Grenze_ab__Ankara_beruft_Nato-Sondersitzung_ein
# 1   Silberstein-Mitarbeiter_Puller_Kurz-Sprecher_bot_100_000_Euro_für_Infos__ÖVP_dementiert
# 1   Geiselnahme_in_Kirche_in_Nordfrankreich_Ein_Attentäter_trug_Fußfessel
# 1   Kurz_will_als_Kanzler_Richtlinienkompetenz
# 82  Immer_mehr_Anzeigen_wegen_Übergriffen_in_Köln__Zahl_der_Täter_unbekannt
# 1   Messerattacken_in_Wien_67-Jähriger_nicht_mehr_in_Lebensgefahr
# 37  Entsetzen_nach_Übergriffen_auf_Frauen_Krisentreffen_in_Köln
# 64  Tausende_Flüchtlinge_in_Spielfeld_Lage_angespannt
# 1   Teenager-Mord_in_Wr__Neustadt_U-Haft_verhängt
# 10  Mazedonien_beugt_sich_Hunderte_Flüchtlinge_überqueren_Grenze
# 1   Fußi_bot_Silberstein-Übersetzerin_Geld_für_Mails_SPÖ_distanziert_sich_von_Berater
# 55  NFL-Liveforum_2016_Playoffs_Diskutieren_Sie_über_American_Football
# 1   Knalleffekt_SP-Bundesgeschäftsführer_Niedermühlbichler_tritt_zurück
# 1   Volkspartei_greift_vor_Kern-Interview_ORF_an
#
#     removed_edges  ratio_edges_removed  largest_cc  ratio_largest_cc  \
# 1   0.0            0.0                  1069.0      0.974476
# 1   0.0            0.0                  1105.0      0.890411
# 46  0.0            0.0                  1063.0      0.899323
# 1   0.0            0.0                  1184.0      0.902439
# 1   0.0            0.0                  943.0       0.950605
# 1   0.0            0.0                  969.0       0.970942
# 1   0.0            0.0                  836.0       0.968714
# 1   0.0            0.0                  1283.0      0.961769
# 1   0.0            0.0                  1083.0      0.971300
# 1   0.0            0.0                  1050.0      0.903614
# 73  0.0            0.0                  1016.0      0.889667
# 1   0.0            0.0                  1060.0      0.865306
# 1   0.0            0.0                  892.0       0.934031
# 1   0.0            0.0                  1099.0      0.960664
# 1   0.0            0.0                  1048.0      0.946703
# 1   0.0            0.0                  1294.0      0.919687
# 1   0.0            0.0                  1073.0      0.960609
# 1   0.0            0.0                  895.0       0.985683
# 1   0.0            0.0                  1316.0      0.971218
# 1   0.0            0.0                  1099.0      0.953166
# 82  0.0            0.0                  937.0       0.968976
# 1   0.0            0.0                  1240.0      0.964230
# 1   0.0            0.0                  1365.0      0.936214
# 1   0.0            0.0                  1076.0      0.945518
# 1   0.0            0.0                  865.0       0.923159
# 1   0.0            0.0                  906.0       0.986928
# 1   0.0            0.0                  1019.0      0.903369
# 1   0.0            0.0                  1131.0      0.952020
# 1   0.0            0.0                  1246.0      0.956989
# 10  0.0            0.0                  1462.0      0.978581
# ..  ...            ...                     ...           ...
# 1   0.0            0.0                  1025.0      0.990338
# 10  0.0            0.0                  853.0       0.988413
# 1   0.0            0.0                  998.0       0.977473
# 1   0.0            0.0                  881.0       0.966009
# 1   0.0            0.0                  1708.0      0.994179
# 1   0.0            0.0                  913.0       0.980666
# 1   0.0            0.0                  2414.0      0.970647
# 1   0.0            0.0                  870.0       0.981941
# 1   0.0            0.0                  780.0       0.989848
# 1   0.0            0.0                  849.0       0.991822
# 82  0.0            0.0                  1703.0      0.987246
# 1   0.0            0.0                  1402.0      0.980420
# 1   0.0            0.0                  1009.0      0.981518
# 64  0.0            0.0                  1173.0      0.991547
# 10  0.0            0.0                  780.0       0.976220
# 1   0.0            0.0                  1169.0      0.982353
# 82  0.0            0.0                  1011.0      0.962857
# 1   0.0            0.0                  1290.0      0.979499
# 1   0.0            0.0                  2033.0      0.992191
# 1   0.0            0.0                  942.0       0.982273
# 82  0.0            0.0                  1514.0      0.998681
# 1   0.0            0.0                  1942.0      0.990816
# 37  0.0            0.0                  830.0       0.994012
# 64  0.0            0.0                  1034.0      0.991371
# 1   0.0            0.0                  1263.0      0.996843
# 10  0.0            0.0                  767.0       0.990956
# 1   0.0            0.0                  1407.0      0.985985
# 55  0.0            0.0                  218.0       0.981982
# 1   0.0            0.0                  1569.0      0.985553
# 1   0.0            0.0                  1077.0      0.984461
#
#       experiment         doc_id
# 1   postings_top  2000103578888
# 1   postings_top  2000066131530
# 46  postings_top  2000036209341
# 1   postings_top  2000101935041
# 1   postings_top  2000102386715
# 1   postings_top  2000050505888
# 1   postings_top  2000088998236
# 1   postings_top  2000041493584
# 1   postings_top  2000035634582
# 1   postings_top  2000037495444
# 73  postings_top  2000021552754
# 1   postings_top  2000074548512
# 1   postings_top  2000072919592
# 1   postings_top  2000097519319
# 1   postings_top  2000066308348
# 1   postings_top  2000074856464
# 1   postings_top  2000098937789
# 1   postings_top  2000050349977
# 1   postings_top  2000066337807
# 1   postings_top  2000022497300
# 82  postings_top  2000023262809
# 1   postings_top  2000088380942
# 1   postings_top  2000087988184
# 1   postings_top  2000053992568
# 1   postings_top  2000067192673
# 1   postings_top  2000098026258
# 1   postings_top  2000086591539
# 1   postings_top  2000103928932
# 1   postings_top  2000101143621
# 10  postings_top  2000037433421
# ..           ...            ...
# 1   postings_top  2000082865663
# 10  postings_top  2000032889550
# 1   postings_top  2000097146278
# 1   postings_top  2000062638686
# 1   postings_top  2000041729911
# 1   postings_top  2000088333356
# 1   postings_top  2000103364196
# 1   postings_top  2000065228620
# 1   postings_top  2000053562077
# 1   postings_top  2000028563372
# 82  postings_top  2000010076421
# 1   postings_top  2000056579232
# 1   postings_top  2000060766463
# 64  postings_top  2000031961692
# 10  postings_top  2000028662791
# 1   postings_top  2000038643468
# 82  postings_top  2000026307773
# 1   postings_top  2000065417586
# 1   postings_top  2000041815368
# 1   postings_top  2000064636685
# 82  postings_top  2000028523248
# 1   postings_top  2000075673167
# 37  postings_top  2000028502118
# 64  postings_top  2000024247292
# 1   postings_top  2000096084363
# 10  postings_top  2000021119514
# 1   postings_top  2000065531147
# 55  postings_top  2000021881754
# 1   postings_top  2000065079710
# 1   postings_top  2000063511763
#
# [200 rows x 9 columns]

# %%
df_gc = df_all.copy()
df_gc[['measure', 'result']].groupby(['measure']).describe()
# Out:
#             result                                                    \
#              count      mean       std       min       25%       50%
# measure
# BC          2000.0  0.171062  0.049502 -0.070988  0.146907  0.177308
# BCC         2000.0  0.458271  0.091190  0.259132  0.392332  0.448694
# EC          2000.0  0.199155  0.120168 -0.157503  0.104755  0.185663
# ECU(corr)   2000.0  0.220359  0.116520 -0.848982  0.148594  0.220641
# ECU(n30)    2000.0  0.070670  0.124059 -1.094336  0.009775  0.067780
# MBLB        2000.0  0.503900  0.134420  0.131298  0.413121  0.502134
# Modularity  2000.0  0.417891  0.045048  0.181968  0.401613  0.426672
# PI          2000.0  0.653659  0.141275  0.173435  0.582505  0.669076
# RWC         2000.0  0.135414  0.238293 -0.629763 -0.023091  0.119603
#
#
#                  75%       max
# measure
# BC          0.203511  0.330272
# BCC         0.513578  0.739235
# EC          0.283807  0.559280
# ECU(corr)   0.301960  0.503550
# ECU(n30)    0.128870  0.549828
# MBLB        0.593248  0.924107
# Modularity  0.447825  0.477006
# PI          0.753877  0.903204
# RWC         0.279135  0.814018

# %%
df_all.to_csv('results_merged.csv')
